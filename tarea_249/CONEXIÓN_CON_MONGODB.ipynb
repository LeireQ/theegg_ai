# %% [markdown]
# # CONEXIÓN A MONGODB CON PYTHON
# <img width = 70%; src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/MongoDB_Logo.svg/2560px-MongoDB_Logo.svg.png">

# %% [markdown]
# ## En este notebook aprenderás a:
# <div style="background-color: rgb(0, 143, 88);margin: 20px; padding: 20px; border-left: 9px solid #ffb200;">
# <ul style="color: rgb(255, 255, 255);font-weight:bold;font-size:15px;">
#     <li style="padding:10px;">Crear una conexión con una BBDD de MongoDB</li>
#     <li style="padding:10px;">Ejecutar nuestras consultas y sentencias MQL con Python.</li>
#     <li style="padding:10px;">Exportar consultas realizadas a una bbdd en MongoDB a JSON.</li>
# </ul>
# </div>

# %% [markdown]
# ## INSTALACIÓN DE PSYCOPG2
# <img width = 20%; src="https://jarroba.com/wp-content/uploads/2015/03/MongoPython.png">
# Lo primero que haremos será instalar la librería de pymongo.
#
# Para ello, puedes pegar esta instrucción en una celda de tipo código de tu notebook:
# >```python
# !pip install pymongo
#
# *Enlace al repo de pypi: https://pypi.org/project/pymongo/*

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\borja\anaconda3\envs\cebanc_pyr\lib\site-packages (4.2.0)

# %% [markdown]
# ## IMPORTACIÓN
#
# Una vez instalado el paquete, lo importamos para poder usarlo.

# %%
import pymongo
from pymongo import MongoClient

# %% [markdown]
# ## CREANDO CONEXIÓN

# %% [markdown]
# Podemos crear la conexión vía string de conexión:

# %%
server ="localhost"
port = 27017
conexion_str =  f"mongodb://{server}:{str(port)}"
conexion = MongoClient(conexion_str)

# %% [markdown]
# O pasándole los parámetros de uno en uno:

# %%
conexion = MongoClient(
    host=server,
    port=port,
    username='',
    password=''
)

# %% [markdown]
# ## Listar los **nombres** de las **bases de datos**

# %%
# listar bases de datos
db_names = conexion.list_database_names()
print(db_names)
# Out:
# ['BBDD_PRUEBA', 'admin', 'config', 'local', 'prueba']

# %% [markdown]
# ## Por cada base de datos listar el **número de colecciones** y diferenciar si son *vistas* o *colecciones*

# %%
# Por cada base de datos listar el número de colecciones y diferenciar si son vistas o colecciones
for db in db_names:
    if db not in ['local','admin','config']:
        print("*"*20)
        coll_names = conexion[db].list_collection_names()
        print(f"La base de datos {db} tiene {len(coll_names)} colecciones y son: {coll_names}")
        views_names = conexion[db].list_collections()
        if views_names:
            for element in list(views_names):
                print(f"La colección con nombre: {element['name']} es de tipo: {element['type']}")
# Out:
# ********************
# La base de datos BBDD_PRUEBA tiene 4 colecciones y son: ['system.views', 'users', 'peliculas', 'mujeres_adultas_por_ciudad']
# La colección con nombre: system.views es de tipo: collection
# La colección con nombre: users es de tipo: collection
# La colección con nombre: peliculas es de tipo: collection
# La colección con nombre: mujeres_adultas_por_ciudad es de tipo: view
# ********************
# La base de datos prueba tiene 2 colecciones y son: ['miembro', 'users']
# La colección con nombre: miembro es de tipo: collection
# La colección con nombre: users es de tipo: collection

# %% [markdown]
# ## Conectarnos a una base de datos concreta

# %%
db = conexion['BBDD_PRUEBA'] # usamos la bbdd de BBDD_PRUEBA

# %% [markdown]
# ## Listar **los nombres de las colecciones** de una base de datos

# %%
# Listar los_nombres de las colecciones de una base de datos
collection_names = db.list_collection_names()
collection_names
# Out:
# ['system.views', 'users', 'peliculas', 'mujeres_adultas_por_ciudad']

# %% [markdown]
# ## Contar los documentos de una colección

# %%
# contar los documentos de la colección users
db[collection_names[1]].count_documents({})
# Out:
# 2141

# %%
db['mujeres_adultas_por_ciudad'].count_documents({})
# Out:
# 298

# %% [markdown]
# ## Contar el número de documentos de cada colección

# %%
# contar el número de documentos de cada colección
for collection in collection_names:
    number_docs = db[collection].count_documents({})
    print(f'La colección  --{collection}--  tiene {number_docs} documentos.')
# Out:
# La colección  --system.views--  tiene 1 documentos.
# La colección  --users--  tiene 2141 documentos.
# La colección  --peliculas--  tiene 4 documentos.
# La colección  --mujeres_adultas_por_ciudad--  tiene 298 documentos.

# %% [markdown]
# ## **Encontrar** el *primer* documento

# %%
db.users.find_one()
# Out:
# {'_id': ObjectId('633b2087f2b6ef2a5eba5b44'),
#  'name': 'BORJA',
#  'age': 51,
#  'gender': 'male',
#  'phone': '982-666-667',
#  'zip_code': 1000,
#  'email': 'b.fernandez@miempresa.com',
#  'city': 'San Sebastián',
#  'nat': 'ES',
#  'last_name': 'Fernández',
#  'aficiones': ['Componer música', 'Pasear']}

# %% [markdown]
# ## Contar los documentos de todxs los users que se llamen Manuel/manuel/MANUEL

# %%
# contar los documentos de todxs los users que se llamen Manuel
db.users.count_documents({"name":{'$regex':'manuel','$options':'i'}})
# Out:
# 14

# %% [markdown]
# ## Iterar sobre cada uno de los documentos:
# - Si la edad (age) existe en el documento, Imprimir por pantalla: "X" tiene "y" años.
# - Si el campo de aficiones existe en el documento, es de tipo dict y no hay valores para las aficiones de invierno, actualizar dichas aficiones con una afición escogida aleatoriamente entre ["ski","lectura","cocinar","cine"]
# - Pasar todos los nombres a mayúsculas

# %%
import pprint
import random
from datetime import datetime
from dateutil.relativedelta import relativedelta
from bson.objectid import ObjectId

aficiones_invierno = ["ski","lectura","cocinar","cine"]
for document in db.users.find():
    obj_id = document['_id']
    nombre = document['name'].upper()
    last_name = document['last_name']
    age = document['age']
    if 'age' in document:
        print(f"{nombre} {last_name} tiene {age} años.")
    if 'aficiones' in document:           
        aficiones = document['aficiones']
        if isinstance(aficiones,dict):
            if aficiones["invierno"] == None:
                aficion = random.choice(aficiones_invierno)
                #upsert: Update or Insert
                db.users.update_one({"_id": ObjectId(obj_id)},{"$set":{"aficiones.invierno":aficion}},upsert=True)
    #upsert: Update or Insert
    db.users.update_one({"_id": ObjectId(obj_id)},{"$set":{"name":nombre.upper()}},upsert=True)
# Out:
# BORJA Fernández tiene 51 años.
# PEDRO Vicente tiene 28 años.
# SILVIA Marin tiene 58 años.
# SUSANA Dominguez tiene 66 años.
# SEBASTIAN Mendoza tiene 55 años.
# JOSEFA Navarro tiene 41 años.
# MONICA Mendez tiene 59 años.
# LUCAS Santana tiene 69 años.
# JAVIER Vazquez tiene 33 años.
# ESTHER Campos tiene 41 años.
# NICOLAS Flores tiene 47 años.
# CLARA Cortes tiene 45 años.
# MARCO Carrasco tiene 28 años.
# LUCAS Gallego tiene 70 años.
# JOHNNY Brown tiene 60 años.
# SILVIA Lozano tiene 29 años.
# EETU Pollari tiene 28 años.
# ENCARNACION Garcia tiene 49 años.
# WAYNE Wright tiene 64 años.
# GUSTAVO Calvo tiene 55 años.
# JOHN Gomez tiene 58 años.
# SYLVIAN Tijs tiene 56 años.
# MARCO Duran tiene 54 años.
# DOLORES Leon tiene 65 años.
# RODRIGO Suarez tiene 57 años.
# ALFONSO Fernandez tiene 58 años.
# JESUS Bravo tiene 32 años.
# ANDREA Hernandez tiene 25 años.
# LORENZO Delgado tiene 39 años.
# STEPHANIE Roberts tiene 62 años.
# LORENA Alvarez tiene 35 años.
# SILVIA Diaz tiene 64 años.
# VILHO Kurtti tiene 28 años.
# SARA Arola tiene 69 años.
# ADRIAN Ramirez tiene 56 años.
# JESUS Gimenez tiene 46 años.
# AATU Aho tiene 58 años.
# VEETI Kauppi tiene 61 años.
# BLANCA Alonso tiene 42 años.
# VILMA Kuusisto tiene 29 años.
# LUCIA Nieto tiene 40 años.
# CLAUDIA Lozano tiene 41 años.
# PURIFICACION Reyes tiene 74 años.
# FRANCISCO Moreno tiene 31 años.
# ESPERANZA Arias tiene 40 años.
# SANTIAGO Vargas tiene 60 años.
# SILVIA Garrido tiene 64 años.
# ELISA Navarro tiene 58 años.
# CONSUELO Suarez tiene 48 años.
# LUCAS Aguilar tiene 64 años.
# MARILOU Bernard tiene 55 años.
# OSCAR Soler tiene 73 años.
# WILLIBRORDUS Joris tiene 49 años.
# ELLEN Phillips tiene 77 años.
# GERARDO Muñoz tiene 38 años.
# GREGORIO Arias tiene 35 años.
# ASUNCION Vicente tiene 45 años.
# NIEVES Saez tiene 48 años.
# NICOLAS Aguilar tiene 33 años.
# MARIA Ortiz tiene 72 años.
# CLAUDIA Gallego tiene 49 años.
# LOUELLA Flokstra tiene 46 años.
# EUGENIO Pascual tiene 56 años.
# LEO Lord tiene 41 años.
# KAYLA Martin tiene 49 años.
# SOPHIA Beck tiene 31 años.
# VILJAMI Karjala tiene 28 años.
# RICARDO Herrero tiene 72 años.
# CELIA Lopez tiene 31 años.
# MARCO Torres tiene 39 años.
# ESPERANZA Lorenzo tiene 28 años.
# ESTHER Torres tiene 39 años.
# ELISA Martin tiene 63 años.
# MARÍA García tiene 33 años.
# JOKIN Murga tiene 18 años.
# UNAI Vicente tiene 28 años.
# MAIALEN Fernández tiene 33 años.
# MIRIAM Pérez tiene 31 años.

# %% [markdown]
# ##  Utilizando las funciones de agregación obtener una lista de documentos de esta forma *[{nombre:x, num_apariciones:y}]*

# %%
# Utilizando las funciones de agregación obtener una 
# lista de documentos de esta forma [{nombre:x, num_apariciones:y}]
cuenta_nombres = list(db.users.aggregate([
    {"$group":{"_id":"$name", "num_apariciones":{"$sum":1}}},
    {"$project":{"_id":0,"nombre":"$_id","num_apariciones":1,}}
]))
cuenta_nombres
# Out:
# [{'num_apariciones': 3, 'nombre': 'NELLI'},
#  {'num_apariciones': 8, 'nombre': 'PATRICIA'},
#  {'num_apariciones': 1, 'nombre': 'PETRONELLA'},
#  {'num_apariciones': 1, 'nombre': 'CELINA'},
#  {'num_apariciones': 8, 'nombre': 'ANGELA'},
#  {'num_apariciones': 2, 'nombre': 'JAMIE'},
#  {'num_apariciones': 1, 'nombre': 'ALAN'},
#  {'num_apariciones': 1, 'nombre': 'LETITIA'},
#  {'num_apariciones': 8, 'nombre': 'TRINIDAD'},
#  {'num_apariciones': 1, 'nombre': 'SUZANNE'},
#  {'num_apariciones': 2, 'nombre': 'AADA'},
#  {'num_apariciones': 3, 'nombre': 'EETU'},
#  {'num_apariciones': 2, 'nombre': 'MAX'},
#  {'num_apariciones': 1, 'nombre': 'JANET'},
#  {'num_apariciones': 2, 'nombre': 'IZZIE'},
#  {'num_apariciones': 2, 'nombre': 'JOONA'},
#  {'num_apariciones': 11, 'nombre': 'RAMON'},
#  {'num_apariciones': 1, 'nombre': 'TAMMY'},
#  {'num_apariciones': 2, 'nombre': 'KRIN'},
#  {'num_apariciones': 15, 'nombre': 'ALEX'},
#  {'num_apariciones': 1, 'nombre': 'CLARISSE'},
#  {'num_apariciones': 1, 'nombre': 'NASH'},
#  {'num_apariciones': 8, 'nombre': 'LUIS'},
#  {'num_apariciones': 3, 'nombre': 'PEPPI'},
#  {'num_apariciones': 1, 'nombre': 'MAXINE'},
#  {'num_apariciones': 1, 'nombre': 'GWENDOLYN'},
#  {'num_apariciones': 2, 'nombre': 'PINJA'},
#  {'num_apariciones': 1, 'nombre': 'ALICE'},
#  {'num_apariciones': 3, 'nombre': 'ELLA'},
#  {'num_apariciones': 1, 'nombre': 'BRITTANY'},
#  {'num_apariciones': 1, 'nombre': 'SYLVIAN'},
#  {'num_apariciones': 14, 'nombre': 'SILVIA'},
#  {'num_apariciones': 6, 'nombre': 'VALENTIN'},
#  {'num_apariciones': 6, 'nombre': 'FELIPE'},
#  {'num_apariciones': 6, 'nombre': 'CARLA'},
#  {'num_apariciones': 12, 'nombre': 'CARMEN'},
#  {'num_apariciones': 1, 'nombre': 'KATE'},
#  {'num_apariciones': 5, 'nombre': 'SOLEDAD'},
#  {'num_apariciones': 9, 'nombre': 'CHRISTIAN'},
#  {'num_apariciones': 1, 'nombre': 'NOELLE'},
#  {'num_apariciones': 1, 'nombre': 'MAËLLE'},
#  {'num_apariciones': 1, 'nombre': 'CAROLINE'},
#  {'num_apariciones': 1, 'nombre': 'MAEVE'},
#  {'num_apariciones': 2, 'nombre': 'WAYNE'},
#  {'num_apariciones': 1, 'nombre': 'YASMIN'},
#  {'num_apariciones': 1, 'nombre': 'CHLOE'},
#  {'num_apariciones': 1, 'nombre': 'STEPHANIE'},
#  {'num_apariciones': 1, 'nombre': 'LOEKIE'},
#  {'num_apariciones': 7, 'nombre': 'ENRIQUE'},
#  {'num_apariciones': 1, 'nombre': 'LOULOU'},
#  {'num_apariciones': 1, 'nombre': 'BORA'},
#  {'num_apariciones': 1, 'nombre': 'LEEVI'},
#  {'num_apariciones': 1, 'nombre': 'GRAEME'},
#  {'num_apariciones': 10, 'nombre': 'JAVIER'},
#  {'num_apariciones': 9, 'nombre': 'JOSEFA'},
#  {'num_apariciones': 13, 'nombre': 'RODRIGO'},
#  {'num_apariciones': 1, 'nombre': 'MATHILDE'},
#  {'num_apariciones': 1, 'nombre': 'MATHEW'},
#  {'num_apariciones': 1, 'nombre': 'OCÉANE'},
#  {'num_apariciones': 1, 'nombre': 'KENNETH'},
#  {'num_apariciones': 2, 'nombre': 'MINTTU'},
#  {'num_apariciones': 1, 'nombre': 'FRENK'},
#  {'num_apariciones': 1, 'nombre': 'DOROTHY'},
#  {'num_apariciones': 1, 'nombre': 'DHIRAJ'},
#  {'num_apariciones': 1, 'nombre': 'TYMO'},
#  {'num_apariciones': 1, 'nombre': 'TERRENCE'},
#  {'num_apariciones': 1, 'nombre': 'ELLI'},
#  {'num_apariciones': 1, 'nombre': 'GABE'},
#  {'num_apariciones': 16, 'nombre': 'LUCAS'},
#  {'num_apariciones': 1, 'nombre': 'JOKIN'},
#  {'num_apariciones': 1, 'nombre': 'ERIK'},
#  {'num_apariciones': 3, 'nombre': 'AINO'},
#  {'num_apariciones': 2, 'nombre': 'ELSA'},
#  {'num_apariciones': 2, 'nombre': 'OONA'},
#  {'num_apariciones': 9, 'nombre': 'ELISA'},
#  {'num_apariciones': 2, 'nombre': 'ROSE'},
#  {'num_apariciones': 1, 'nombre': 'FAYE'},
#  {'num_apariciones': 2, 'nombre': 'DOMINGO'},
#  {'num_apariciones': 7, 'nombre': 'GERMAN'},
#  {'num_apariciones': 2, 'nombre': 'JULIUS'},
#  {'num_apariciones': 1, 'nombre': 'BOY'},
#  {'num_apariciones': 2, 'nombre': 'ELEANOR'},
#  {'num_apariciones': 3, 'nombre': 'MILAGROS'},
#  {'num_apariciones': 1, 'nombre': 'LLOYD'},
#  {'num_apariciones': 8, 'nombre': 'MARIA'},
#  {'num_apariciones': 1, 'nombre': 'TRISTAN'},
#  {'num_apariciones': 1, 'nombre': 'JOSEF'},
#  {'num_apariciones': 4, 'nombre': 'ANA'},
#  {'num_apariciones': 5, 'nombre': 'CRISTIAN'},
#  {'num_apariciones': 4, 'nombre': 'EUGENIA'},
#  {'num_apariciones': 1, 'nombre': 'SIMON'},
#  {'num_apariciones': 1, 'nombre': 'DEANNA'},
#  {'num_apariciones': 1, 'nombre': 'JANNY'},
#  {'num_apariciones': 2, 'nombre': 'TRACY'},
#  {'num_apariciones': 13, 'nombre': 'LAURA'},
#  {'num_apariciones': 1, 'nombre': 'ELIZABETH'},
#  {'num_apariciones': 1, 'nombre': 'REINARDUS'},
#  {'num_apariciones': 1, 'nombre': 'WILLIAM'},
#  {'num_apariciones': 1, 'nombre': 'JORINA'},
#  {'num_apariciones': 2, 'nombre': 'AKSELI'},
#  {'num_apariciones': 1, 'nombre': 'SHERRY'},
#  {'num_apariciones': 1, 'nombre': 'ZOÉ'},
#  {'num_apariciones': 1, 'nombre': 'GERALD'},
#  {'num_apariciones': 3, 'nombre': 'OLIVER'},
#  {'num_apariciones': 1, 'nombre': 'MILTON'},
#  {'num_apariciones': 1, 'nombre': 'COLIN'},
#  {'num_apariciones': 12, 'nombre': 'ALBERTO'},
#  {'num_apariciones': 7, 'nombre': 'SERGIO'},
#  {'num_apariciones': 8, 'nombre': 'IKER'},
#  {'num_apariciones': 1, 'nombre': 'ISABELLA'},
#  {'num_apariciones': 1, 'nombre': 'CHANTAL'},
#  {'num_apariciones': 5, 'nombre': 'CATALINA'},
#  {'num_apariciones': 9, 'nombre': 'JORDI'},
#  {'num_apariciones': 4, 'nombre': 'EMILIO'},
#  {'num_apariciones': 1, 'nombre': 'SIMEON'},
#  {'num_apariciones': 1, 'nombre': 'AYFER'},
#  {'num_apariciones': 1, 'nombre': 'IRFAN'},
#  {'num_apariciones': 10, 'nombre': 'VANESA'},
#  {'num_apariciones': 1, 'nombre': 'DYLLAN'},
#  {'num_apariciones': 1, 'nombre': 'PAULINE'},
#  {'num_apariciones': 1, 'nombre': 'BERNARD'},
#  {'num_apariciones': 1, 'nombre': 'UNAI'},
#  {'num_apariciones': 1, 'nombre': 'LAURI'},
#  {'num_apariciones': 7, 'nombre': 'ALICIA'},
#  {'num_apariciones': 1, 'nombre': 'KARUNA'},
#  {'num_apariciones': 10, 'nombre': 'EVA'},
#  {'num_apariciones': 1, 'nombre': 'SETH'},
#  {'num_apariciones': 1, 'nombre': 'LOUISE'},
#  {'num_apariciones': 17, 'nombre': 'AGUSTIN'},
#  {'num_apariciones': 1, 'nombre': 'ROOPE'},
#  {'num_apariciones': 1, 'nombre': 'OUMAÏMA'},
#  {'num_apariciones': 1, 'nombre': 'LINDA'},
#  {'num_apariciones': 1, 'nombre': 'CORY'},
#  {'num_apariciones': 3, 'nombre': 'JESSE'},
#  {'num_apariciones': 1, 'nombre': 'ABBAS'},
#  {'num_apariciones': 1, 'nombre': 'SAANA'},
#  {'num_apariciones': 1, 'nombre': 'WADE'},
#  {'num_apariciones': 7, 'nombre': 'PURIFICACION'},
#  {'num_apariciones': 1, 'nombre': 'KELYA'},
#  {'num_apariciones': 9, 'nombre': 'JOSEFINA'},
#  {'num_apariciones': 9, 'nombre': 'JULIO'},
#  {'num_apariciones': 1, 'nombre': 'ANTON'},
#  {'num_apariciones': 1, 'nombre': 'JESSA'},
#  {'num_apariciones': 8, 'nombre': 'JONATHAN'},
#  {'num_apariciones': 7, 'nombre': 'JULIAN'},
#  {'num_apariciones': 1, 'nombre': 'DAN'},
#  {'num_apariciones': 3, 'nombre': 'EMMI'},
#  {'num_apariciones': 9, 'nombre': 'JULIA'},
#  {'num_apariciones': 4, 'nombre': 'GEMA'},
#  {'num_apariciones': 3, 'nombre': 'KERTTU'},
#  {'num_apariciones': 1, 'nombre': 'FLORENT'},
#  {'num_apariciones': 1, 'nombre': 'REGINA'},
#  {'num_apariciones': 12, 'nombre': 'CLARA'},
#  {'num_apariciones': 1, 'nombre': 'KAYLA'},
#  {'num_apariciones': 15, 'nombre': 'FRANCISCO'},
#  {'num_apariciones': 10, 'nombre': 'CARLOS'},
#  {'num_apariciones': 8, 'nombre': 'ANTONIA'},
#  {'num_apariciones': 2, 'nombre': 'NELLA'},
#  {'num_apariciones': 11, 'nombre': 'ISMAEL'},
#  {'num_apariciones': 1, 'nombre': 'CALEB'},
#  {'num_apariciones': 1, 'nombre': 'TIMOTHE'},
#  {'num_apariciones': 1, 'nombre': 'BOB'},
#  {'num_apariciones': 1, 'nombre': 'PATRIQUE'},
#  {'num_apariciones': 1, 'nombre': 'DJEN'},
#  {'num_apariciones': 7, 'nombre': 'MARTIN'},
#  {'num_apariciones': 2, 'nombre': 'SHERRI'},
#  {'num_apariciones': 1, 'nombre': 'TIM'},
#  {'num_apariciones': 6, 'nombre': 'VICENTA'},
#  {'num_apariciones': 1, 'nombre': 'CARRY'},
#  {'num_apariciones': 2, 'nombre': 'VILHO'},
#  {'num_apariciones': 1, 'nombre': 'TIJMEN'},
#  {'num_apariciones': 6, 'nombre': 'TOMAS'},
#  {'num_apariciones': 2, 'nombre': 'SARAH'},
#  {'num_apariciones': 1, 'nombre': 'LOUISA'},
#  {'num_apariciones': 1, 'nombre': 'DOUGLAS'},
#  {'num_apariciones': 1, 'nombre': 'RHONDA'},
#  {'num_apariciones': 7, 'nombre': 'MIRIAM'},
#  {'num_apariciones': 1, 'nombre': 'JUDITH'},
#  {'num_apariciones': 12, 'nombre': 'EUGENIO'},
#  {'num_apariciones': 11, 'nombre': 'VERONICA'},
#  {'num_apariciones': 20, 'nombre': 'ADRIAN'},
#  {'num_apariciones': 11, 'nombre': 'JOAN'},
#  {'num_apariciones': 8, 'nombre': 'VICENTE'},
#  {'num_apariciones': 1, 'nombre': 'HISKE'},
#  {'num_apariciones': 1, 'nombre': 'FRANKIE'},
#  {'num_apariciones': 10, 'nombre': 'MARIANO'},
#  {'num_apariciones': 1, 'nombre': 'GAËLLE'},
#  {'num_apariciones': 1, 'nombre': 'VICKY'},
#  {'num_apariciones': 7, 'nombre': 'JORGE'},
#  {'num_apariciones': 6, 'nombre': 'FATIMA'},
#  {'num_apariciones': 2, 'nombre': 'OLIVIA'},
#  {'num_apariciones': 6, 'nombre': 'LUISA'},
#  {'num_apariciones': 1, 'nombre': 'AUSTIN'},
#  {'num_apariciones': 2, 'nombre': 'VEETI'},
#  {'num_apariciones': 1, 'nombre': 'ROBERT'},
#  {'num_apariciones': 6, 'nombre': 'PEDRO'},
#  {'num_apariciones': 3, 'nombre': 'AMANDA'},
#  {'num_apariciones': 1, 'nombre': 'JOURI'},
#  {'num_apariciones': 1, 'nombre': 'RODNEY'},
#  {'num_apariciones': 1, 'nombre': 'RKIA'},
#  {'num_apariciones': 7, 'nombre': 'IGNACIO'},
#  {'num_apariciones': 12, 'nombre': 'DANIEL'},
#  {'num_apariciones': 3, 'nombre': 'VILMA'},
#  {'num_apariciones': 6, 'nombre': 'GLORIA'},
#  {'num_apariciones': 1, 'nombre': 'JARED'},
#  {'num_apariciones': 1, 'nombre': 'KAYLEE'},
#  {'num_apariciones': 3, 'nombre': 'OLGA'},
#  {'num_apariciones': 9, 'nombre': 'CELIA'},
#  {'num_apariciones': 1, 'nombre': 'MOUNA'},
#  {'num_apariciones': 1, 'nombre': 'NUNO'},
#  {'num_apariciones': 7, 'nombre': 'ROBERTO'},
#  {'num_apariciones': 6, 'nombre': 'GABRIEL'},
#  {'num_apariciones': 6, 'nombre': 'ANDRES'},
#  {'num_apariciones': 6, 'nombre': 'CONCEPCION'},
#  {'num_apariciones': 9, 'nombre': 'CARMELO'},
#  {'num_apariciones': 1, 'nombre': 'TIMOTHY'},
#  {'num_apariciones': 1, 'nombre': 'SHARENA'},
#  {'num_apariciones': 2, 'nombre': 'ERIN'},
#  {'num_apariciones': 1, 'nombre': 'MAIALEN'},
#  {'num_apariciones': 2, 'nombre': 'EELI'},
#  {'num_apariciones': 1, 'nombre': 'KOMAL'},
#  {'num_apariciones': 1, 'nombre': 'PHILIP'},
#  {'num_apariciones': 9, 'nombre': 'MARGARITA'},
#  {'num_apariciones': 1, 'nombre': 'TERRANCE'},
#  {'num_apariciones': 2, 'nombre': 'TYRONE'},
#  {'num_apariciones': 1, 'nombre': 'VALENTINA'},
#  {'num_apariciones': 1, 'nombre': 'FABIO'},
#  {'num_apariciones': 1, 'nombre': 'KATHERINE'},
#  {'num_apariciones': 1, 'nombre': 'JOVANNY'},
#  {'num_apariciones': 1, 'nombre': 'ADÈLE'},
#  {'num_apariciones': 9, 'nombre': 'ALFONSO'},
#  {'num_apariciones': 4, 'nombre': 'INMACULADA'},
#  {'num_apariciones': 11, 'nombre': 'PAULA'},
#  {'num_apariciones': 7, 'nombre': 'FRANCISCA'},
#  {'num_apariciones': 4, 'nombre': 'AITOR'},
#  {'num_apariciones': 1, 'nombre': 'EVELINE'},
#  {'num_apariciones': 1, 'nombre': 'GREG'},
#  {'num_apariciones': 6, 'nombre': 'SALVADOR'},
#  {'num_apariciones': 1, 'nombre': 'SIIRI'},
#  {'num_apariciones': 3, 'nombre': 'IIDA'},
#  {'num_apariciones': 1, 'nombre': 'KIRK'},
#  {'num_apariciones': 3, 'nombre': 'VENLA'},
#  {'num_apariciones': 1, 'nombre': 'MABEL'},
#  {'num_apariciones': 5, 'nombre': 'SARA'},
#  {'num_apariciones': 6, 'nombre': 'ALFREDO'},
#  {'num_apariciones': 1, 'nombre': 'BARBARA'},
#  {'num_apariciones': 7, 'nombre': 'JUANA'},
#  {'num_apariciones': 1, 'nombre': 'NAËL'},
#  {'num_apariciones': 1, 'nombre': 'MAËVA'},
#  {'num_apariciones': 1, 'nombre': 'TAYLOR'},
#  {'num_apariciones': 1, 'nombre': 'TARIQ'},
#  {'num_apariciones': 6, 'nombre': 'ANTONIO'},
#  {'num_apariciones': 12, 'nombre': 'ALBERT'},
#  {'num_apariciones': 8, 'nombre': 'MANUELA'},
#  {'num_apariciones': 9, 'nombre': 'LIDIA'},
#  {'num_apariciones': 8, 'nombre': 'MARTA'},
#  {'num_apariciones': 2, 'nombre': 'VEERA'},
#  {'num_apariciones': 1, 'nombre': 'ELIAN'},
#  {'num_apariciones': 14, 'nombre': 'JOAQUIN'},
#  {'num_apariciones': 1, 'nombre': 'DAMIANO'},
#  {'num_apariciones': 1, 'nombre': 'LANDON'},
#  {'num_apariciones': 1, 'nombre': 'MORGAN'},
#  {'num_apariciones': 1, 'nombre': 'ARI'},
#  {'num_apariciones': 1, 'nombre': 'SOPHIE'},
#  {'num_apariciones': 11, 'nombre': 'LOURDES'},
#  {'num_apariciones': 1, 'nombre': 'SOPHIA'},
#  {'num_apariciones': 2, 'nombre': 'CAROL'},
#  {'num_apariciones': 1, 'nombre': 'JEROME'},
#  {'num_apariciones': 1, 'nombre': 'MIKE'},
#  {'num_apariciones': 1, 'nombre': 'JON'},
#  {'num_apariciones': 1, 'nombre': 'GAIL'},
#  {'num_apariciones': 7, 'nombre': 'LUZ'},
#  {'num_apariciones': 1, 'nombre': 'PERRY'},
#  {'num_apariciones': 5, 'nombre': 'SONIA'},
#  {'num_apariciones': 3, 'nombre': 'TOIVO'},
#  {'num_apariciones': 1, 'nombre': 'ALISA'},
#  {'num_apariciones': 1, 'nombre': 'XANDRA'},
#  {'num_apariciones': 1, 'nombre': 'ELIZA'},
#  {'num_apariciones': 1, 'nombre': 'NICHOLAS'},
#  {'num_apariciones': 1, 'nombre': 'DARYL'},
#  {'num_apariciones': 1, 'nombre': 'OWEN'},
#  {'num_apariciones': 8, 'nombre': 'LORENA'},
#  {'num_apariciones': 1, 'nombre': 'ALFRED'},
#  {'num_apariciones': 1, 'nombre': 'OUAFAE'},
#  {'num_apariciones': 9, 'nombre': 'RICARDO'},
#  {'num_apariciones': 1, 'nombre': 'ROMAIN'},
#  {'num_apariciones': 1, 'nombre': 'TOBY'},
#  {'num_apariciones': 1, 'nombre': 'AMY'},
#  {'num_apariciones': 6, 'nombre': 'ALEXANDER'},
#  {'num_apariciones': 9, 'nombre': 'MOHAMED'},
#  {'num_apariciones': 1, 'nombre': 'ELIAS'},
#  {'num_apariciones': 1, 'nombre': 'LINA'},
#  {'num_apariciones': 1, 'nombre': 'VERA'},
#  {'num_apariciones': 1, 'nombre': 'DENNIS'},
#  {'num_apariciones': 8, 'nombre': 'DAVID'},
#  {'num_apariciones': 1, 'nombre': 'DEAN'},
#  {'num_apariciones': 1, 'nombre': 'HANNA'},
#  {'num_apariciones': 1, 'nombre': 'ROËL'},
#  {'num_apariciones': 10, 'nombre': 'CRISTINA'},
#  {'num_apariciones': 3, 'nombre': 'ISLA'},
#  {'num_apariciones': 2, 'nombre': 'SANNI'},
#  {'num_apariciones': 1, 'nombre': 'SCARLETT'},
#  {'num_apariciones': 1, 'nombre': 'BARBERA'},
#  {'num_apariciones': 15, 'nombre': 'BEGOÑA'},
#  {'num_apariciones': 10, 'nombre': 'SEBASTIAN'},
#  {'num_apariciones': 1, 'nombre': 'SEMIH'},
#  {'num_apariciones': 10, 'nombre': 'OSCAR'},
#  {'num_apariciones': 3, 'nombre': 'AURORA'},
#  {'num_apariciones': 12, 'nombre': 'IVAN'},
#  {'num_apariciones': 1, 'nombre': 'LUUKAS'},
#  {'num_apariciones': 9, 'nombre': 'FELIX'},
#  {'num_apariciones': 4, 'nombre': 'ELLEN'},
#  {'num_apariciones': 1, 'nombre': 'IMRAAN'},
#  {'num_apariciones': 12, 'nombre': 'CAROLINA'},
#  {'num_apariciones': 11, 'nombre': 'ISAAC'},
#  {'num_apariciones': 1, 'nombre': 'QUENTIN'},
#  {'num_apariciones': 1, 'nombre': 'LÉA'},
#  {'num_apariciones': 6, 'nombre': 'JOSEP'},
#  {'num_apariciones': 9, 'nombre': 'NEREA'},
#  {'num_apariciones': 1, 'nombre': 'KESTER'},
#  {'num_apariciones': 7, 'nombre': 'GUILLERMO'},
#  {'num_apariciones': 1, 'nombre': 'CHANDNI'},
#  {'num_apariciones': 9, 'nombre': 'ADOLFO'},
#  {'num_apariciones': 1, 'nombre': 'MYA'},
#  {'num_apariciones': 1, 'nombre': 'SALIH'},
#  {'num_apariciones': 1, 'nombre': 'LUCAS OR LUKE'},
#  {'num_apariciones': 1, 'nombre': 'ALEXANDRA'},
#  {'num_apariciones': 2, 'nombre': 'VALTTERI'},
#  {'num_apariciones': 8, 'nombre': 'RAQUEL'},
#  {'num_apariciones': 6, 'nombre': 'PABLO'},
#  {'num_apariciones': 2, 'nombre': 'BRYAN'},
#  {'num_apariciones': 5, 'nombre': 'GONZALO'},
#  {'num_apariciones': 7, 'nombre': 'MARC'},
#  {'num_apariciones': 1, 'nombre': 'KAREN'},
#  {'num_apariciones': 2, 'nombre': 'EINO'},
#  {'num_apariciones': 1, 'nombre': 'RAVENNA'},
#  {'num_apariciones': 1, 'nombre': 'LAYLA'},
#  {'num_apariciones': 1, 'nombre': 'CHRISTOPHER'},
#  {'num_apariciones': 1, 'nombre': 'JUHO'},
#  {'num_apariciones': 1, 'nombre': 'RITA'},
#  {'num_apariciones': 3, 'nombre': 'LENNI'},
#  {'num_apariciones': 1, 'nombre': 'HENRY'},
#  {'num_apariciones': 6, 'nombre': 'ALEJANDRA'},
#  {'num_apariciones': 6, 'nombre': 'ANGELES'},
#  {'num_apariciones': 5, 'nombre': 'BLANCA'},
#  {'num_apariciones': 6, 'nombre': 'NURIA'},
#  {'num_apariciones': 1, 'nombre': 'KATHRYN'},
#  {'num_apariciones': 5, 'nombre': 'NATALIA'},
#  {'num_apariciones': 8, 'nombre': 'CESAR'},
#  {'num_apariciones': 1, 'nombre': 'CHARLES'},
#  {'num_apariciones': 9, 'nombre': 'NOELIA'},
#  {'num_apariciones': 9, 'nombre': 'HECTOR'},
#  {'num_apariciones': 2, 'nombre': 'RONJA'},
#  {'num_apariciones': 6, 'nombre': 'BENITO'},
#  {'num_apariciones': 2, 'nombre': 'HOWARD'},
#  {'num_apariciones': 2, 'nombre': 'AATU'},
#  {'num_apariciones': 1, 'nombre': 'NEELKE'},
#  {'num_apariciones': 1, 'nombre': 'JIMI'},
#  {'num_apariciones': 12, 'nombre': 'ERNESTO'},
#  {'num_apariciones': 14, 'nombre': 'ALEJANDRO'},
#  {'num_apariciones': 1, 'nombre': 'MICHELLE'},
#  {'num_apariciones': 1, 'nombre': 'HANS'},
#  {'num_apariciones': 1, 'nombre': 'AMALIA'},
#  {'num_apariciones': 1, 'nombre': 'JULIE'},
#  {'num_apariciones': 1, 'nombre': 'STEEF'},
#  {'num_apariciones': 1, 'nombre': 'TRACEY'},
#  {'num_apariciones': 8, 'nombre': 'RUBEN'},
#  {'num_apariciones': 1, 'nombre': 'LUCIEN'},
#  {'num_apariciones': 12, 'nombre': 'BORJA'},
#  {'num_apariciones': 1, 'nombre': 'MILLA'},
#  {'num_apariciones': 1, 'nombre': 'JAZZ'},
#  {'num_apariciones': 1, 'nombre': 'SUSAN'},
#  {'num_apariciones': 7, 'nombre': 'EMILIA'},
#  {'num_apariciones': 6, 'nombre': 'ENCARNACION'},
#  {'num_apariciones': 10, 'nombre': 'RAUL'},
#  {'num_apariciones': 3, 'nombre': 'SUSANA'},
#  {'num_apariciones': 9, 'nombre': 'ANGEL'},
#  {'num_apariciones': 2, 'nombre': 'NOOA'},
#  {'num_apariciones': 9, 'nombre': 'SANDRA'},
#  {'num_apariciones': 1, 'nombre': 'MARY'},
#  {'num_apariciones': 1, 'nombre': 'ARLENE'},
#  {'num_apariciones': 1, 'nombre': 'MARCEL'},
#  {'num_apariciones': 14, 'nombre': 'DANIELA'},
#  {'num_apariciones': 1, 'nombre': 'NICOLE'},
#  {'num_apariciones': 1, 'nombre': 'ONNI'},
#  {'num_apariciones': 11, 'nombre': 'GREGORIO'},
#  {'num_apariciones': 1, 'nombre': 'ALEXIS'},
#  {'num_apariciones': 1, 'nombre': 'KIARA'},
#  {'num_apariciones': 19, 'nombre': 'JOSE'},
#  {'num_apariciones': 1, 'nombre': 'SAIRA'},
#  {'num_apariciones': 1, 'nombre': 'RUSSELL'},
#  {'num_apariciones': 10, 'nombre': 'ALVARO'},
#  {'num_apariciones': 1, 'nombre': 'KIMBERLEY'},
#  {'num_apariciones': 9, 'nombre': 'NIEVES'},
#  {'num_apariciones': 1, 'nombre': 'EEMELI'},
#  {'num_apariciones': 1, 'nombre': 'THAÏS'},
#  {'num_apariciones': 1, 'nombre': 'MELISSA'},
#  {'num_apariciones': 2, 'nombre': 'PEETU'},
#  {'num_apariciones': 7, 'nombre': 'ROCIO'},
#  {'num_apariciones': 3, 'nombre': 'MARIO'},
#  {'num_apariciones': 1, 'nombre': 'CELENA'},
#  {'num_apariciones': 1, 'nombre': 'ROLAND'},
#  {'num_apariciones': 1, 'nombre': 'SERRA'},
#  {'num_apariciones': 5, 'nombre': 'LINNEA'},
#  {'num_apariciones': 12, 'nombre': 'INES'},
#  {'num_apariciones': 1, 'nombre': 'NATASHA'},
#  {'num_apariciones': 1, 'nombre': 'A'},
#  {'num_apariciones': 1, 'nombre': 'VÄINÖ'},
#  {'num_apariciones': 2, 'nombre': 'PHOEBE'},
#  {'num_apariciones': 1, 'nombre': 'THIAGO'},
#  {'num_apariciones': 8, 'nombre': 'YOLANDA'},
#  {'num_apariciones': 1, 'nombre': 'SHANITA'},
#  {'num_apariciones': 1, 'nombre': 'EMMY'},
#  {'num_apariciones': 2, 'nombre': 'ALISON'},
#  {'num_apariciones': 2, 'nombre': 'HILLA'},
#  {'num_apariciones': 1, 'nombre': 'ESTELLA'},
#  {'num_apariciones': 1, 'nombre': 'WILMA'},
#  {'num_apariciones': 3, 'nombre': 'MAR'},
#  {'num_apariciones': 1, 'nombre': 'VINESH'},
#  {'num_apariciones': 2, 'nombre': 'JOEL'},
#  {'num_apariciones': 1, 'nombre': 'MARGOT'},
#  {'num_apariciones': 1, 'nombre': 'BIEKE'},
#  {'num_apariciones': 1, 'nombre': 'DEBRA'},
#  {'num_apariciones': 1, 'nombre': 'GLENDA'},
#  {'num_apariciones': 9, 'nombre': 'DOLORES'},
#  {'num_apariciones': 1, 'nombre': 'IIRIS'},
#  {'num_apariciones': 1, 'nombre': 'DÉJAN'},
#  {'num_apariciones': 8, 'nombre': 'JUAN'},
#  {'num_apariciones': 15, 'nombre': 'CONSUELO'},
#  {'num_apariciones': 1, 'nombre': 'FRANKLIN'},
#  {'num_apariciones': 4, 'nombre': 'CRISTOBAL'},
#  {'num_apariciones': 9, 'nombre': 'ISABEL'},
#  {'num_apariciones': 1, 'nombre': 'LISON'},
#  {'num_apariciones': 2, 'nombre': 'TOPIAS'},
#  {'num_apariciones': 8, 'nombre': 'FERNANDO'},
#  {'num_apariciones': 1, 'nombre': 'SHERYL'},
#  {'num_apariciones': 9, 'nombre': 'MARINA'},
#  {'num_apariciones': 4, 'nombre': 'SOFIA'},
#  {'num_apariciones': 1, 'nombre': 'LOUELLA'},
#  {'num_apariciones': 1, 'nombre': 'TARA'},
#  {'num_apariciones': 1, 'nombre': 'MEEUWIS'},
#  {'num_apariciones': 9, 'nombre': 'ASUNCION'},
#  {'num_apariciones': 1, 'nombre': 'NESIBE'},
#  {'num_apariciones': 1, 'nombre': 'BERFIN'},
#  {'num_apariciones': 12, 'nombre': 'NICOLAS'},
#  {'num_apariciones': 9, 'nombre': 'LUCIA'},
#  {'num_apariciones': 8, 'nombre': 'ALBA'},
#  {'num_apariciones': 1, 'nombre': 'NIILO'},
#  {'num_apariciones': 6, 'nombre': 'MANUEL'},
#  {'num_apariciones': 1, 'nombre': 'DENIZ'},
#  {'num_apariciones': 1, 'nombre': 'GILBERT'},
#  {'num_apariciones': 2, 'nombre': 'EEVI'},
#  {'num_apariciones': 1, 'nombre': 'SADÉ'},
#  {'num_apariciones': 11, 'nombre': 'ESPERANZA'},
#  {'num_apariciones': 1, 'nombre': 'ARIE'},
#  {'num_apariciones': 2, 'nombre': 'MINEA'},
#  {'num_apariciones': 3, 'nombre': 'HELMI'},
#  {'num_apariciones': 1, 'nombre': 'ALBERTA'},
#  {'num_apariciones': 1, 'nombre': 'DAVE'},
#  {'num_apariciones': 11, 'nombre': 'ANNA'},
#  {'num_apariciones': 1, 'nombre': 'ROMÉO'},
#  {'num_apariciones': 12, 'nombre': 'ROSARIO'},
#  {'num_apariciones': 1, 'nombre': 'SAMANTHA'},
#  {'num_apariciones': 1, 'nombre': 'AAPO'},
#  {'num_apariciones': 1, 'nombre': 'ADRIEN'},
#  {'num_apariciones': 7, 'nombre': 'CLAUDIA'},
#  {'num_apariciones': 1, 'nombre': 'JIPPE'},
#  {'num_apariciones': 8, 'nombre': 'ANDREA'},
#  {'num_apariciones': 7, 'nombre': 'ELENA'},
#  {'num_apariciones': 1, 'nombre': 'SHAILA'},
#  {'num_apariciones': 1, 'nombre': 'LUMI'},
#  {'num_apariciones': 8, 'nombre': 'JAIME'},
#  {'num_apariciones': 5, 'nombre': 'PILAR'},
#  {'num_apariciones': 1, 'nombre': 'MARÍA'},
#  {'num_apariciones': 3, 'nombre': 'IRENE'},
#  {'num_apariciones': 7, 'nombre': 'ESTEBAN'},
#  {'num_apariciones': 2, 'nombre': 'LOTTA'},
#  {'num_apariciones': 17, 'nombre': 'JESUS'},
#  {'num_apariciones': 7, 'nombre': 'MAGDALENA'},
#  {'num_apariciones': 7, 'nombre': 'XAVIER'},
#  {'num_apariciones': 1, 'nombre': 'WILLIE'},
#  {'num_apariciones': 1, 'nombre': 'JOHNNY'},
#  {'num_apariciones': 1, 'nombre': 'WILLARD'},
#  {'num_apariciones': 2, 'nombre': 'NIKLAS'},
#  {'num_apariciones': 1, 'nombre': 'MELANIE'},
#  {'num_apariciones': 1, 'nombre': 'LOLA'},
#  {'num_apariciones': 9, 'nombre': 'TERESA'},
#  {'num_apariciones': 1, 'nombre': 'LEO'},
#  {'num_apariciones': 6, 'nombre': 'JOHN'},
#  {'num_apariciones': 4, 'nombre': 'SAMUEL'},
#  {'num_apariciones': 5, 'nombre': 'MONTSERRAT'},
#  {'num_apariciones': 1, 'nombre': 'ENOLA'},
#  {'num_apariciones': 9, 'nombre': 'VICTORIA'},
#  {'num_apariciones': 1, 'nombre': 'YEŞIM'},
#  {'num_apariciones': 1, 'nombre': 'ZOE'},
#  {'num_apariciones': 11, 'nombre': 'MERCEDES'},
#  {'num_apariciones': 1, 'nombre': 'DIO'},
#  {'num_apariciones': 1, 'nombre': 'SAHAR'},
#  {'num_apariciones': 1, 'nombre': 'KAY'},
#  {'num_apariciones': 6, 'nombre': 'MARCOS'},
#  {'num_apariciones': 1, 'nombre': 'ELIZABET'},
#  {'num_apariciones': 1, 'nombre': 'KATIE'},
#  {'num_apariciones': 1, 'nombre': 'GORDON'},
#  {'num_apariciones': 1, 'nombre': 'CALVIN'},
#  {'num_apariciones': 1, 'nombre': 'LILIAN'},
#  {'num_apariciones': 1, 'nombre': 'AVERY'},
#  {'num_apariciones': 10, 'nombre': 'VIRGINIA'},
#  {'num_apariciones': 1, 'nombre': 'WILLIBRORDUS'},
#  {'num_apariciones': 1, 'nombre': 'MARTHA'},
#  {'num_apariciones': 1, 'nombre': 'WILMER'},
#  {'num_apariciones': 1, 'nombre': 'JUSTIN'},
#  {'num_apariciones': 13, 'nombre': 'MONICA'},
#  {'num_apariciones': 1, 'nombre': 'ROEF'},
#  {'num_apariciones': 5, 'nombre': 'HUGO'},
#  {'num_apariciones': 2, 'nombre': 'MIKAEL'},
#  {'num_apariciones': 8, 'nombre': 'ROSA'},
#  {'num_apariciones': 11, 'nombre': 'DIEGO'},
#  {'num_apariciones': 5, 'nombre': 'LORENZO'},
#  {'num_apariciones': 14, 'nombre': 'AMPARO'},
#  {'num_apariciones': 1, 'nombre': 'ANGELINA'},
#  {'num_apariciones': 1, 'nombre': 'ALEXIA'},
#  {'num_apariciones': 1, 'nombre': 'CLARENCE'},
#  {'num_apariciones': 2, 'nombre': 'PIHLA'},
#  {'num_apariciones': 7, 'nombre': 'BELEN'},
#  {'num_apariciones': 1, 'nombre': 'BRETT'},
#  {'num_apariciones': 12, 'nombre': 'VICTOR'},
#  {'num_apariciones': 1, 'nombre': 'RAUF'},
#  {'num_apariciones': 1, 'nombre': 'JESSIE'},
#  {'num_apariciones': 1, 'nombre': 'EDUARDUS'},
#  {'num_apariciones': 8, 'nombre': 'BEATRIZ'},
#  {'num_apariciones': 7, 'nombre': 'EDUARDO'},
#  {'num_apariciones': 1, 'nombre': 'CHINOUK'},
#  {'num_apariciones': 1, 'nombre': 'IDSKE'},
#  {'num_apariciones': 4, 'nombre': 'ARTTU'},
#  {'num_apariciones': 1, 'nombre': 'DUSTIN'},
#  {'num_apariciones': 4, 'nombre': 'GUSTAVO'},
#  {'num_apariciones': 1, 'nombre': 'VINOD'},
#  {'num_apariciones': 1, 'nombre': 'MARGIE'},
#  {'num_apariciones': 9, 'nombre': 'MIGUEL'},
#  {'num_apariciones': 1, 'nombre': 'CHARLIE'},
#  {'num_apariciones': 1, 'nombre': 'MIRO'},
#  {'num_apariciones': 2, 'nombre': 'ENNI'},
#  {'num_apariciones': 1, 'nombre': 'MARILOU'},
#  {'num_apariciones': 2, 'nombre': 'EUGENE'},
#  {'num_apariciones': 15, 'nombre': 'MARCO'},
#  {'num_apariciones': 12, 'nombre': 'RAFAEL'},
#  {'num_apariciones': 1, 'nombre': 'SHAUNI'},
#  {'num_apariciones': 1, 'nombre': 'AMBRE'},
#  {'num_apariciones': 1, 'nombre': 'VILJAMI'},
#  {'num_apariciones': 1, 'nombre': 'JEANNE'},
#  {'num_apariciones': 2, 'nombre': 'PHILLIP'},
#  {'num_apariciones': 9, 'nombre': 'REMEDIOS'},
#  {'num_apariciones': 1, 'nombre': 'BILLIE'},
#  {'num_apariciones': 11, 'nombre': 'ESTHER'},
#  {'num_apariciones': 13, 'nombre': 'GERARDO'},
#  {'num_apariciones': 11, 'nombre': 'ADRIANA'},
#  {'num_apariciones': 2, 'nombre': 'EEMIL'},
#  {'num_apariciones': 8, 'nombre': 'ARTURO'},
#  {'num_apariciones': 12, 'nombre': 'SANTIAGO'},
#  {'num_apariciones': 1, 'nombre': 'ROELFINA'},
#  {'num_apariciones': 2, 'nombre': 'SAMU'},
#  {'num_apariciones': 1, 'nombre': 'CHAD'},
#  {'num_apariciones': 1, 'nombre': 'RORY'},
#  {'num_apariciones': 1, 'nombre': 'LENA'},
#  {'num_apariciones': 1, 'nombre': 'JORY'},
#  {'num_apariciones': 1, 'nombre': 'MARION'},
#  {'num_apariciones': 1, 'nombre': 'IINA'}]

# %% [markdown]
# ## Exportar el resultado en un **fichero JSON** que tenga por nombre algo como: **20220301203032_cuenta_nombres.json**

# %%
import pandas as pd
pd.DataFrame(cuenta_nombres)
# Out:
#      num_apariciones      nombre
# 0                  3       NELLI
# 1                  8    PATRICIA
# 2                  1  PETRONELLA
# 3                  1      CELINA
# 4                  8      ANGELA
# ..               ...         ...
# 562                1        RORY
# 563                1        LENA
# 564                1        JORY
# 565                1      MARION
# 566                1        IINA
#
# [567 rows x 2 columns]

# %%
from datetime import datetime

# exportar el resultado en un fichero JSON que tenga por nombre algo como: 20220301203032_cuenta_nombres.json
import json
fecha_= datetime.now().strftime("%Y%m%d%H%M%S")
with open(f'{fecha_}_cuenta_nombres.json', 'w',encoding='utf8') as f:
    json.dump(cuenta_nombres, f, ensure_ascii=False)

# %% [markdown]
# ## Leer de nuevo dicho archivo y obtener el número de apariciones de la persona cuyo nombre es MANUELA

# %%
# Leer de nuevo dicho archivo y obtener el número de apariciones de la persona cuyo nombre es MANUELA
with open(f'{fecha_}_cuenta_nombres.json',encoding="utf8") as json_file:
    data = json.load(json_file)

# %%
[doc["num_apariciones"] for doc in data if doc["nombre"] == "MANUELA"]
# Out:
# [8]

# %% [markdown]
# ## Leer de nuevo el archivo **users.json**
# - Imprimir la el **número** de documentos
# - Incluir únicamente los documentos que tengan **más de 3 claves**.
# - Si existe la llave edad, comprobar si es de tipo datetime.datetime y si no lo es parsearla como tal.
# - **Si el campo email es nulo**, crearlo a partir del nombre+apellido@gmail.com

# %%
# Leer de archivo users.json
with open(f'users_to_mongo.json',encoding='utf8') as json_file:
    new_docs = json.load(json_file)
    print(len(new_docs))
# Out:
# 9

# %%
new_docs
# Out:
# [{'name': 'Manuel',
#   'last_name': 'González',
#   'email': 'mgonzalez@cbnc.com',
#   'age': '1992-12-12',
#   'profesion': 'Pianista',
#   'salario_mensual_actual': 2500,
#   'formacion_academica': {'universidad': 'ehu',
#    'fp': 'ils',
#    'bachillerato': 'ils'},
#   'exp_profesional': {'orquesta_sinfónica_euskadi': ['Pianista', 2]},
#   'aficiones': {'verano': 'playa', 'invierno': ['ski', 'snow']},
#   'coche': True,
#   'direccion': {'municipio': 'irun',
#    'cp': 20000,
#    'barrio': 'meaka',
#    'provincia': 'gipuzkoa',
#    'ccaa': 'País Vasco'},
#   'sexo': 'hombre',
#   'estado_civil': 'casado',
#   'hijos': 2,
#   'idiomas': {'espaniol': ['nativo', 'intermedio']},
#   'peliculas': [1, 3, 4]},
#  {'name': 'Oscar',
#   'last_name': 'González',
#   'email': 'ogonzalez@cbnc.com',
#   'age': '1990-12-31',
#   'profesion': 'Barrendero',
#   'salario_mensual_actual': 1650,
#   'exp_profesional': {'ayto_municipal': ['Barrendero', 5]},
#   'aficiones': {'verano': 'viajar', 'invierno': ['lectura']},
#   'coche': False},
#  {'name': 'Susana',
#   'last_name': 'Etxebeste',
#   'email': 'ogonzalez@cbnc.com',
#   'age': '2002-07-31',
#   'aficiones': {'verano': 'viajar', 'invierno': ['lectura']},
#   'coche': False,
#   'sexo': 'mujer'},
#  {'name': 'Oscar',
#   'last_name': 'Pérez',
#   'email': None,
#   'age': '1999-07-31',
#   'aficiones': {'verano': 'playa', 'invierno': ['viajar', 'lectura']},
#   'coche': False,
#   'sexo': 'hombre'},
#  {'name': 'María',
#   'last_name': 'Domínguez',
#   'email': None,
#   'age': '1963-07-31',
#   'profesion': 'Matemática',
#   'aficiones': {'verano': 'playa', 'invierno': ['viajar', 'lectura']},
#   'coche': False,
#   'sexo': 'mujer'},
#  {'name': 'Ana',
#   'last_name': 'Rubio',
#   'email': None,
#   'age': '1988-07-31',
#   'profesion': 'Traductora',
#   'salario_mensual_actual': 1400,
#   'aficiones': {'verano': 'playa', 'invierno': ['viajar', 'lectura']},
#   'coche': True,
#   'sexo': 'mujer'},
#  {'name': 'Oscar'},
#  {'name': 'Susana'},
#  {'name': 'Diana'}]

# %%
from dateutil.relativedelta import relativedelta

docs_a_importar = []
print(f"La longitud del archivo es de: {len(new_docs)} documentos.")
for doc in new_docs:
    claves = doc.keys()
    if len(claves) > 3:
        if "age" in claves:
            fecha = doc["age"]
            doc["age"] = age = relativedelta(datetime.now(), datetime.strptime(fecha, "%Y-%m-%d")).years
        if not doc["email"]:
            doc["email"] = doc["name"].lower() + doc["last_name"].lower() + "@gmail.com"
        docs_a_importar.append(doc)
print(f"La longitud final de documentos a importar es dee: {len(docs_a_importar)} documentos.")
# Out:
# La longitud del archivo es de: 9 documentos.
# La longitud final de documentos a importar es dee: 6 documentos.

# %% [markdown]
# ## Insertar los nuevos documentos

# %%
# Insertar los nuevos documentos
db.users.insert_many(new_docs)

# %% [markdown]
# ## Pasar todos los **apellidos a mayúsculas**

# %%
# Pasar todos los **nombres propios a mayúsculas**
db.users.update_many({},[{"$set":{"last_name":{"$toUpper":"$last_name"}}}])

# %% [markdown]
# ## Eliminar todos los users que tengan 3 keys o menos

# %%
# eliminar todos los users que tengan 3 keys o menos
una_key_docs = []
for doc in db.users.find():
    if len(doc.keys()) <=3:
        _id = doc['_id']
        db.users.delete_one({"_id":ObjectId(_id)})

# %% [markdown]
# ## Eliminar la vista "mujeres_adultas_por_ciudad"

# %%
# Eliminar la vista "mujeres_adultas_por_ciudad"
db.mujeres_adultas_por_ciudad.drop()

# %% [markdown]
# ## Cerrar sesión

# %%
conexion.close()

# %% [markdown]
# <div style="background-color:  #FFCB92;margin: 20px; padding: 20px">
# <b>¡Hasta la próxima pequeñx gran Egger!</b> 🐣 Ya estás un pasito más cerca de lograr tus metas!
# </div>
